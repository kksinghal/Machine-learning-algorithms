# %%
from sklearn import datasets
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/train.csv")
df
# Out:
#      Pclass                                            Name     Sex   Age  \
# 0         2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1         3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2         2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3         3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4         3                          Sutehall, Mr. Henry Jr    male  25.0
# ..      ...                                             ...     ...   ...
# 663       2                             Ilett, Miss. Bertha  female  17.0
# 664       3                        Morrow, Mr. Thomas Rowan    male   NaN
# 665       3                                   Bing, Mr. Lee    male  32.0
# 666       3                     Strandberg, Miss. Ida Sofia  female  22.0
# 667       3                  Murphy, Miss. Katherine "Kate"  female   NaN
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked  Survived
# ...

# %%
df.drop("Name", axis=1, inplace=True) #Name is not a feature for our model
df.drop("Ticket", axis=1, inplace=True) #Ticket is not a feature for our model
df.drop("Cabin", axis=1, inplace=True)
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0         2  female  29.0      1      0  26.0000        S         1
# 1         3    male   NaN      0      0   8.0500        S         0
# 2         2    male  39.0      0      0  26.0000        S         0
# 3         3  female  29.0      0      4  21.0750        S         0
# 4         3    male  25.0      0      0   7.0500        S         0
# ..      ...     ...   ...    ...    ...      ...      ...       ...
# 663       2  female  17.0      0      0  10.5000        S         1
# 664       3    male   NaN      0      0   7.7500        Q         0
# 665       3    male  32.0      0      0  56.4958        S         1
# 666       3  female  22.0      0      0   9.8375        S         0
# 667       3  female   NaN      1      0  15.5000        Q         1
#
# [668 rows x 8 columns]

# %%
print(len(df["Embarked"]=="S"))
print(df[df["Embarked"]=="S"]["Survived"].sum())

print(len(df["Embarked"]=="C"))
print(df[df["Embarked"]=="C"]["Survived"].sum())

print(len(df["Embarked"]=="Q"))
print(df[df["Embarked"]=="Q"]["Survived"].sum())

#Since, number of people survived is radically different for people from each port. 
# "Embarked" is an important feature 
N = df.index.stop
df["PortS"]=0
df["PortC"]=0
df["PortQ"]=0
for i in range(N):
    if(df.iloc[i, 6]=="S"):
        df.iloc[i, 8] = 1
    elif(df.iloc[i, 6]=="C"):
        df.iloc[i, 9] = 1
    else:
        df.iloc[i, 10] = 1
df.drop("Embarked", axis=1, inplace=True)
# Out:
# 668
# 173
# 668
# 75
# 668
# 20

# %%
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare  Survived  PortS  PortC  \
# 0         2  female  29.0      1      0  26.0000         1      1      0
# 1         3    male   NaN      0      0   8.0500         0      1      0
# 2         2    male  39.0      0      0  26.0000         0      1      0
# 3         3  female  29.0      0      4  21.0750         0      1      0
# 4         3    male  25.0      0      0   7.0500         0      1      0
# ..      ...     ...   ...    ...    ...      ...       ...    ...    ...
# 663       2  female  17.0      0      0  10.5000         1      1      0
# 664       3    male   NaN      0      0   7.7500         0      0      0
# 665       3    male  32.0      0      0  56.4958         1      1      0
# 666       3  female  22.0      0      0   9.8375         0      1      0
# 667       3  female   NaN      1      0  15.5000         1      0      0
#
#      PortQ
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# ...

# %%
print(len(df["Pclass"]==1))
print(df[df["Pclass"]==1]["Survived"].sum())

print(len(df["Pclass"]==2))
print(df[df["Pclass"]==2]["Survived"].sum())

print(len(df["Pclass"]==3))
print(df[df["Pclass"]==3]["Survived"].sum())
# Out:
# 668
# 105
# 668
# 72
# 668
# 92

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
plt.scatter(df["Fare"], df["Survived"])
plt.show()
#Fare is useless
df.drop("Fare", axis=1, inplace=True)
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch  Survived  PortS  PortC  PortQ
# 0         2  female  29.0      1      0         1      1      0      0
# 1         3    male   NaN      0      0         0      1      0      0
# 2         2    male  39.0      0      0         0      1      0      0
# 3         3  female  29.0      0      4         0      1      0      0
# 4         3    male  25.0      0      0         0      1      0      0
# ..      ...     ...   ...    ...    ...       ...    ...    ...    ...
# 663       2  female  17.0      0      0         1      1      0      0
# 664       3    male   NaN      0      0         0      0      0      1
# 665       3    male  32.0      0      0         1      1      0      0
# 666       3  female  22.0      0      0         0      1      0      0
# 667       3  female   NaN      1      0         1      0      0      1
#
# [668 rows x 9 columns]

# %%
plt.style.use("dark_background")
plt.scatter(df["Parch"], df["Survived"])
plt.show()
#Parch is useless
df.drop("Parch", axis=1, inplace=True)
df
# Out:
#      Pclass     Sex   Age  SibSp  Survived  PortS  PortC  PortQ
# 0         2  female  29.0      1         1      1      0      0
# 1         3    male   NaN      0         0      1      0      0
# 2         2    male  39.0      0         0      1      0      0
# 3         3  female  29.0      0         0      1      0      0
# 4         3    male  25.0      0         0      1      0      0
# ..      ...     ...   ...    ...       ...    ...    ...    ...
# 663       2  female  17.0      0         1      1      0      0
# 664       3    male   NaN      0         0      0      0      1
# 665       3    male  32.0      0         1      1      0      0
# 666       3  female  22.0      0         0      1      0      0
# 667       3  female   NaN      1         1      0      0      1
#
# [668 rows x 8 columns]

# %%
plt.style.use("dark_background")
plt.scatter(df["SibSp"], df["Survived"])
plt.show()
#SibSp is useless
df.drop("SibSp", axis=1, inplace=True)
df
# Out:
#      Pclass     Sex   Age  Survived  PortS  PortC  PortQ
# 0         2  female  29.0         1      1      0      0
# 1         3    male   NaN         0      1      0      0
# 2         2    male  39.0         0      1      0      0
# 3         3  female  29.0         0      1      0      0
# 4         3    male  25.0         0      1      0      0
# ..      ...     ...   ...       ...    ...    ...    ...
# 663       2  female  17.0         1      1      0      0
# 664       3    male   NaN         0      0      0      1
# 665       3    male  32.0         1      1      0      0
# 666       3  female  22.0         0      1      0      0
# 667       3  female   NaN         1      0      0      1
#
# [668 rows x 7 columns]

# %%
plt.style.use("dark_background")
plt.scatter(df["Age"], df["Survived"])
plt.show()
#Age is useless
df.drop("Age", axis=1, inplace=True)
df
# Out:
#      Pclass     Sex  Survived  PortS  PortC  PortQ
# 0         2  female         1      1      0      0
# 1         3    male         0      1      0      0
# 2         2    male         0      1      0      0
# 3         3  female         0      1      0      0
# 4         3    male         0      1      0      0
# ..      ...     ...       ...    ...    ...    ...
# 663       2  female         1      1      0      0
# 664       3    male         0      0      0      1
# 665       3    male         1      1      0      0
# 666       3  female         0      1      0      0
# 667       3  female         1      0      0      1
#
# [668 rows x 6 columns]

# %%
def convertToClasses(i):
    if(i=='male'):
        return 1
    return -1
df.Sex = df.Sex.apply(convertToClasses)
df
# Out:
#      Pclass  Sex  Survived  PortS  PortC  PortQ
# 0         2   -1         1      1      0      0
# 1         3    1         0      1      0      0
# 2         2    1         0      1      0      0
# 3         3   -1         0      1      0      0
# 4         3    1         0      1      0      0
# ..      ...  ...       ...    ...    ...    ...
# 663       2   -1         1      1      0      0
# 664       3    1         0      0      0      1
# 665       3    1         1      1      0      0
# 666       3   -1         0      1      0      0
# 667       3   -1         1      0      0      1
#
# [668 rows x 6 columns]

# %%
X = df.iloc[:, [0,1,3,4,5]]
Y = df.iloc[:, 2]

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X, Y)
# Out:
# LogisticRegression()

# %%
model.score(X, Y)
# Out:
# 0.7664670658682635

# %%
df_test = pd.read_csv("./data/test.csv")
df_test
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         2                     Davies, Master. John Morgan Jr    male   8.0
# 1         1                        Leader, Dr. Alice (Farnham)  female  49.0
# 2         3                            Kilgannon, Mr. Thomas J    male   NaN
# 3         2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0
# 4         1                          McGough, Mr. James Robert    male  36.0
# ..      ...                                                ...     ...   ...
# 218       3                        Lindqvist, Mr. Eino William    male  20.0
# 219       1                  Butt, Major. Archibald Willingham    male  45.0
# 220       1  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0
# 221       3                   Holm, Mr. John Fredrik Alexander    male  43.0
# 222       2           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5
#
# ...

# %%
df_test.drop("Name", axis=1, inplace=True) 
df_test.drop("Ticket", axis=1, inplace=True) 
df_test.drop("Cabin", axis=1, inplace=True)

df_test["PortS"]=0
df_test["PortC"]=0
df_test["PortQ"]=0
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked  PortS  PortC  \
# 0         2    male   8.0      1      1   36.7500        S      0      0
# 1         1  female  49.0      0      0   25.9292        S      0      0
# 2         3    male   NaN      0      0    7.7375        Q      0      0
# 3         2  female  24.0      2      1   27.0000        S      0      0
# 4         1    male  36.0      0      0   26.2875        S      0      0
# ..      ...     ...   ...    ...    ...       ...      ...    ...    ...
# 218       3    male  20.0      1      0    7.9250        S      0      0
# 219       1    male  45.0      0      0   26.5500        S      0      0
# 220       1  female  17.0      1      0  108.9000        C      0      0
# 221       3    male  43.0      0      0    6.4500        S      0      0
# 222       2    male  36.5      0      2   26.0000        S      0      0
#
#      PortQ
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# ...

# %%
N = df_test.index.stop
for i in range(N):
    if(df_test.iloc[i, 6]=="S"):
        df_test.iloc[i, 7] = 1
    elif(df_test.iloc[i, 6]=="C"):
        df_test.iloc[i, 8] = 1
    else:
        df_test.iloc[i, 9] = 1
df_test.drop("Embarked", axis=1, inplace=True)
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare  PortS  PortC  PortQ
# 0         2    male   8.0      1      1   36.7500      1      0      0
# 1         1  female  49.0      0      0   25.9292      1      0      0
# 2         3    male   NaN      0      0    7.7375      0      0      1
# 3         2  female  24.0      2      1   27.0000      1      0      0
# 4         1    male  36.0      0      0   26.2875      1      0      0
# ..      ...     ...   ...    ...    ...       ...    ...    ...    ...
# 218       3    male  20.0      1      0    7.9250      1      0      0
# 219       1    male  45.0      0      0   26.5500      1      0      0
# 220       1  female  17.0      1      0  108.9000      0      1      0
# 221       3    male  43.0      0      0    6.4500      1      0      0
# 222       2    male  36.5      0      2   26.0000      1      0      0
#
# [223 rows x 9 columns]

# %%
df_test.drop("Fare", axis=1, inplace=True)
df_test.drop("Parch", axis=1, inplace=True)
df_test.drop("SibSp", axis=1, inplace=True)
df_test.drop("Age", axis=1, inplace=True)
def convertToClasses(i):
    if(i=='male'):
        return 1
    return -1
df_test.Sex = df_test.Sex.apply(convertToClasses)
df_test
# Out:
#      Pclass  Sex  PortS  PortC  PortQ
# 0         2    1      1      0      0
# 1         1   -1      1      0      0
# 2         3    1      0      0      1
# 3         2   -1      1      0      0
# 4         1    1      1      0      0
# ..      ...  ...    ...    ...    ...
# 218       3    1      1      0      0
# 219       1    1      1      0      0
# 220       1   -1      0      1      0
# 221       3    1      1      0      0
# 222       2    1      1      0      0
#
# [223 rows x 5 columns]

# %%
pred = model.predict(df_test)
np.savetxt("predictions.csv", pred)
